# %% [markdown]
# <a href="https://colab.research.google.com/github/JennEYoon/ECG-transform/blob/main/demo_2026/predict_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Prediction Model, v2
# filename: predict_v2.ipynb, on Colab
# Part of "demo_2026" folder, sub-topic
# Owner: Jennnifer Yoon
# Date: March 21, 2026 Saturday
#
# ***input files***
# *.npy, *.hea
#
# ***output files***
# predictv1.pth
# *.png
# *.csv - controller file, peak detect

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !mkdir mydata
# Out:
# mkdir: cannot create directory ‘mydata’: File exists

# %%
# !ls -h
# Out:
# mydata	sample_data

# %%
data_url = "https://github.com/JennEYoon/ECG-transform/trunk/data_public/data_predict"

# %%
print(data_url)
# Out:
# https://github.com/JennEYoon/ECG-transform/trunk/data_public/data_predict

# %% [markdown]
# ### Install `subversion`
#
# Since `svn` command was not found, we need to install the `subversion` package. This is a system-level tool that allows us to use `svn export` to download specific folders from GitHub repositories.

# %%
# Install subversion package
# !apt-get install -y subversion

print("Subversion installed successfully. You can now use 'svn export'.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# subversion is already the newest version (1.14.1-3ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Subversion installed successfully. You can now use 'svn export'.

# %% [markdown]
# ### GitHub Folder Download
#
# To download a specific folder from a public GitHub repository, we can use the `svn export` command, which allows selective checkout of subdirectories without cloning the entire repository. The `dataurl` variable (defined in cell `R0e9nNqVg4yv`) now contains the svn-compatible URL of the target GitHub folder.

# %% [markdown]
# ### Download from new GitHub folder using `data_url`
#
# This section uses the `data_url` variable (defined in cell `l7UY6ibPkBKz`) to download another specific folder from a public GitHub repository. We will again use the `svn export` command-line tool for this purpose.

# %%
import os

# Define the output directory (reusing 'mydata' or choose a new one if preferred)
# If you want a separate directory, change 'mydata' to something like 'mydata_predict'
output_dir = "mydata"
os.makedirs(output_dir, exist_ok=True) # Ensure the directory exists

# The data_url variable is defined in cell l7UY6ibPkBKz
# It should contain the svn-compatible URL of the GitHub folder.

print(f"Downloading folder from GitHub URL: {data_url} to {output_dir}")

# Use svn export to download the specific folder
# svn command-line tool is usually available in Colab environments.
# !svn export "$data_url" "$output_dir"

print("GitHub folder download complete from new URL.")
# Out:
# ...
# svn: E170013: Unable to connect to a repository at URL 'https://github.com/JennEYoon/ECG-transform/tree/main/data_public/data_predict'
# svn: E160013: '/JennEYoon/ECG-transform/tree/main/data_public/data_predict' path not found
# GitHub folder download complete from new URL.

# %%
# !ls ./mydata/

# %%
import os

# Define the output directory
output_dir = "mydata"
os.makedirs(output_dir, exist_ok=True) # Ensure the directory exists

# The data_url variable is defined in a previous cell (l7UY6ibPkBKz)
# It should contain the svn-compatible URL of the GitHub folder.

print(f"Downloading folder from GitHub URL: {data_url} to {output_dir}")

# Use svn export to download the specific folder
# svn command-line tool is usually available in Colab environments.
# !svn export "$data_url" "$output_dir"

print("GitHub folder download complete.")
# Out:
# ...
# svn: E170013: Unable to connect to a repository at URL 'https://github.com/JennEYoon/ECG-transform/tree/main/data_public/data_predict'
# svn: E160013: '/JennEYoon/ECG-transform/tree/main/data_public/data_predict' path not found
# GitHub folder download complete.
